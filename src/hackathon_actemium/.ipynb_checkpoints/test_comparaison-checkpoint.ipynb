# %%
import pandas as pd
import numpy as np

from models_tests.arimas.arima_pipeline import ARIMAPipeline
from models_tests.ETS_HoltsWinter.ets_pipeline import ETSPipeline
from models_tests.tcn.pipeline import TCNPipeline 
from dl_model.pipeline_lstm import LSTMWrapper
from analyse.modele_comparaison import compare_models
# Out:
# 2026-04-23 15:06:40.060044: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-23 15:06:41.745218: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-23 15:06:44.176551: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# LOAD DATA
df = pd.read_csv("WADI_clean.csv")

target = "3_LT_001_PV"

# features = tout sauf target
X = df.drop(columns=[target])
y = df[target]

# Valeurs manquantes complétées
X = X.ffill()

# garder que numérique
X = X.select_dtypes(include=[np.number])


# SPLIT (time series)
split_1 = int(len(df) * 0.7)
split_2 = int(len(df) * 0.85)

X_train = X.iloc[:split_1]
y_train = y.iloc[:split_1]

X_val = X.iloc[split_1:split_2]
y_val = y.iloc[split_1:split_2]

X_test = X.iloc[split_2:]
y_test = y.iloc[split_2:]

print("Train:", X_train.shape)
print("Validation:", X_val.shape)
print("Test :", X_test.shape)
# Out:
# Train: (142881, 120)
# Validation: (30617, 120)
# Test : (30618, 120)

# %%
y_train_val = pd.concat([y_train, y_val])
X_train_val = pd.concat([X_train, X_val])

# %%
pipe = ARIMAPipeline()
pipe.fit(y_train_val, X_train=X_train_val)

pred_arima = pipe.predict(
    n_steps=len(y_test),      # longueur du test
    X_future=X_test,          # si exogènes
    n_train=len(y_train_val)  # indique au modèle où commence la prédiction
)

# %%
pipe = ETSPipeline()
pipe.fit(y_train_val)


preds_ets = pipe.predict(len(y_test))
# Out:
# /u2/users/cycle3/sipahimalani/.local/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err

# %%
pipe = LSTMWrapper()   # rien à configurer

pipe.fit(X_train, y_train, X_val, y_val)

pred_lstm = pipe.predict(len(y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 120, 64)           47360
#
#  dropout (Dropout)           (None, 120, 64)           0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 59809 (233.63 KB)
# Trainable params: 59809 (233.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
train_df = pd.concat([y_train, X_train], axis=1)
val_df = pd.concat([y_val, X_val], axis=1)

# %%
pipe = TCNPipeline()

pipe.fit(train_df, val_df)

preds_tcn = pipe.predict(len(y_test))

# %%
results = {"ARIMA" : {"pred": pred_arima}, "ETS" : {"pred": preds_ets}}

# %%
df_compare = compare_models(results_dict=results, y_true=y_test)
# Out:
# COMPARAISON MODELES
#    model      RMSE       MAE  SkillScore
# 0  ARIMA  1.518637  0.976383  -27.811975
# 1    ETS  1.522923  0.978761  -27.893288
