# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

from dl_model.trainer_lstm import train_lstm
from outils.gridsearch import grid_search
# Out:
# 2026-04-21 11:33:46.968104: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-21 11:33:47.009670: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-21 11:33:47.010766: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-21 11:33:48.423233: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Chargement du jeu de données
df = pd.read_csv("WADI_clean.csv")

target = "3_LT_001_PV" # pour l'instant on ne le fait que sur une cible


# features = tout sauf la target
X = df.drop(columns=[target])
y = df[target]

# Suppression des colonnes non numériques
X = X.select_dtypes(include=[np.number])

# Split
# /!\ : pas de shuffle pour séries temporelles

split_1 = int(len(df) * 0.7)
split_2 = int(len(df) * 0.85)

X_train = X.iloc[:split_1]
y_train = y.iloc[:split_1]

X_val = X.iloc[split_1:split_2]
y_val = y.iloc[split_1:split_2]

X_test  = X.iloc[split_2:]
y_test  = y.iloc[split_2:]

print("Train:", X_train.shape)
print("Validation:", X_val.shape)
print("Test :", X_test.shape)

# Gridsearch
p_grid = {
    "model_type": ["lstm", "gru"],
    "batch_size": [64, 128],# premier test
    "epochs": [20],
    "verbose": [0] # pour empêcher de tout voir
}

df_results = grid_search(
    trainer=train_lstm,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    p_grid=p_grid,
    score_opt="val_loss"
)

print(df_results)
# Out:
# Train: (699, 120)
# Validation: (150, 120)
# Test : (150, 120)
# GridSearch lancé sur 4 combinaisons
# Parallelisation avec n_jobs=-1
# 2026-04-21 11:33:54.083966: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-21 11:33:54.115155: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-21 11:33:54.122381: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-21 11:33:54.129228: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-21 11:33:54.129676: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-21 11:33:54.160124: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-21 11:33:54.160507: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-21 11:33:54.166986: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-21 11:33:54.167434: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-21 11:33:54.176599: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-21 11:33:54.219901: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-21 11:33:54.220269: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-21 11:33:55.569178: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-04-21 11:33:55.634547: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-04-21 11:33:55.656946: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-04-21 11:33:55.726555: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 120, 64)           47360
#
#  dropout (Dropout)           (None, 120, 64)           0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 59809 (233.63 KB)
# Trainable params: 59809 (233.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 120, 64)           47360
#
#  dropout (Dropout)           (None, 120, 64)           0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 59809 (233.63 KB)
# Trainable params: 59809 (233.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#  Meilleurs paramètres (val_loss) :
# model_type            gru
# batch_size             64
# epochs                 20
# verbose                 0
# val_loss      2552.862061
# val_mae         50.525818
# Name: 2, dtype: object
# Score: 2552.862060546875
#   model_type  batch_size  epochs  verbose     val_loss    val_mae
# 0       lstm          64      20        0  2609.518555  51.083408
# 1       lstm         128      20        0  2860.527588  53.483868
# 2        gru          64      20        0  2552.862061  50.525818
# 3        gru         128      20        0  2805.425049  52.966232

# %%
best = df_results.loc[df_results["val_loss"].idxmin()]

# %%
model, scaler, history = train_lstm(
    X_train, y_train,
    X_val, y_val,
    model_type=best["model_type"],
    batch_size=int(best["batch_size"]),
    epochs=int(best["epochs"])
)
# Out:
# Epoch 1/20
# 10/10 [==============================] -
# 10/10 [==============================] - 1s 59ms/step - loss: 2846.0701 - mae: 53.3384 - val_loss: 2829.4531 - val_mae: 53.1926 - lr: 0.0010
# Epoch 17/20
# 10/10 [==============================] - 1s 60ms/step - loss: 2818.5376 - mae: 53.0796 - val_loss: 2794.2500 - val_mae: 52.8606 - lr: 0.0010
# Epoch 18/20
# 10/10 [==============================] - 1s 58ms/step - loss: 2778.0710 - mae: 52.6955 - val_loss: 2759.5146 - val_mae: 52.5311 - lr: 0.0010
# Epoch 19/20
# 10/10 [==============================] - 1s 59ms/step - loss: 2744.3901 - mae: 52.3748 - val_loss: 2725.1282 - val_mae: 52.2027 - lr: 0.0010
# Epoch 20/20
# 10/10 [==============================] - 1s 58ms/step - loss: 2708.9536 - mae: 52.0355 - val_loss: 2691.1025 - val_mae: 51.8758 - lr: 0.0010

# %%
from dl_model.sequences_lstm import prepare_sequences

# %%
X_test_seq, y_test_seq = prepare_sequences(scaler.transform(X_test), y_test.values)

X_test_seq = X_test_seq.reshape((X_test_seq.shape[0], X_test_seq.shape[1], X_test_seq.shape[2]))

model.evaluate(X_test_seq, y_test_seq)
# Out:
# 1/1 [==============================] - 0s 36ms/step - loss: 2686.4636 - mae: 51.8311
# [2686.463623046875, 51.83106231689453]

# %%
# Prédiction

# %%
from dl_model.forecast_lstm import forecast_lstm_direct
from dl_model.config_lstm import WINDOW_SIZE

# %%
preds = forecast_lstm_direct(model=model,
    val=X_test,        # ou une partie récente du dataset
    scaler=scaler,
    saisonalite=WINDOW_SIZE)
# Out:
# /u2/users/cycle3/sipahimalani/.local/lib/python3.8/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 preds = forecast_lstm_direct(model=model,
#       2     val=X_test,        # ou une partie récente du dataset
#       3     scaler=scaler,
#       4     saisonalite=WINDOW_SIZE)
#
# File ~/Documents/MAS/hackaton/Hackathon2026Actemium/src/hackathon_actemium/dl_model/forecast_lstm.py:34, in forecast_lstm_direct(model, val, scaler, saisonalite)
#      32 def forecast_lstm_direct(model, val, scaler, saisonalite):
#      33     # scaler comme dans ton entraînement
# ---> 34     val_scaled = scaler.transform(val.values.reshape(-1, 1))
#      36     # dernière fenêtre
#      37     last_window = val_scaled[-saisonalite:]
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~/.local/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:515, in MinMaxScaler.transform(self, X)
#     501 """Scale features of X according to feature_range.
#     502
#     503 Parameters
#    (...)
#     511     Transformed data.
#     512 """
#     513 check_is_fitted(self)
# --> 515 X = self._validate_data(
#     516     X,
#     517     copy=self.copy,
#     518     dtype=FLOAT_DTYPES,
#     519     force_all_finite="allow-nan",
#     520     reset=False,
#     521 )
#     523 X *= self.scale_
#     524 X += self.min_
#
# File ~/.local/lib/python3.8/site-packages/sklearn/base.py:626, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
# --> 626     self._check_n_features(X, reset=reset)
#     628 return out
#
# File ~/.local/lib/python3.8/site-packages/sklearn/base.py:415, in BaseEstimator._check_n_features(self, X, reset)
#     412     return
#     414 if n_features != self.n_features_in_:
# --> 415     raise ValueError(
#     416         f"X has {n_features} features, but {self.__class__.__name__} "
#     417         f"is expecting {self.n_features_in_} features as input."
#     418     )
#
# ValueError: X has 1 features, but MinMaxScaler is expecting 120 features as input.
